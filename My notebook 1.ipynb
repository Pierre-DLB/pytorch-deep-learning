# %%
import torch 
from torch import nn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.set_context()

# %% [markdown]
# # Create a classification model (neural network)

# %% [markdown]
# Also read the doc : how to save and load a model.

# %%
from sklearn.datasets import make_circles

# Make 1000 samples for each of the 2 regions.

X, y = make_circles(n_samples=1000, factor=.6, noise = 0.05, random_state=1)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
df = pd.DataFrame(X, columns=['x1', 'x2'])

# %%
df["y"]= y

# %%
df.head()
# Out:
#          x1        x2  y
# 0  0.663165 -0.005038  1
# 1 -0.402833 -0.528074  1
# 2  0.874093 -0.641097  0
# 3 -0.095011 -0.944484  0
# 4 -1.006072  0.173870  0

# %%
### check input and output shapes
print(f"X has shape {X.shape}")
print(f"y has shape {y.shape}")
# Out:
# X has shape (1000, 2)
# y has shape (1000,)

# %%
### turn data into tensors

X = torch.from_numpy(X).type(torch.float32)
y = torch.from_numpy(y).type(torch.float32)

### create train and test sets.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
# Out:
# tensor([[-0.2893,  0.4977],
#         [ 0.2445, -0.5897],
#         [-0.8976, -0.4751],
#         ...,
#         [ 0.0819, -0.9797],
#         [ 0.3453, -0.4639],
#         [-0.5022,  0.2119]])

# %% [markdown]
# ## Building a model to classify the dots

# %% [markdown]
# The things to do :
#
# 1) Setup device agnostic code, so the code can run on CPU or GPU.
# 2) Create a module (Subclassing nn.Module)
# 3) Define a loss and optimizer
# 4) Train the model, and test it.

# %%
# make device agnostic : 

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# construction of the model

# - Subclass nn.Module (all models are subclasses of nn.Module)
# - 2 nn.Linear layers (capable of handeling the data)
# - define a foward method (outlines the forward pass of our data)
# - Instanciare an instance of our model and send it to device

# 1. Subclass nn.Module

class CircleModel(nn.Module):
    def __inint__():
        super.__init__()
        # create 2 nn.linear layers
        self.layer_1 = nn.Linear(in_features=2, out_features=5)
        self.layer_2 = nn.Linear(in_features=5, out_features=1)

    def forward(self, x):
# Out:
# 'cpu'
